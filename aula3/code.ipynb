# %%
# Apply a mean filter
import numpy as np
from PIL import Image  
from numpy import asarray
import matplotlib.pyplot as plt

# %%
def main():
    # Open image
    image = Image.open('Images/lena.jpg')
    #image.show()
    plt.imshow(image)
    # convert image to numpy array    
    npImage = np.array(image) 
    npImageFilter = np.empty(npImage.shape)

    # values os a windows 5 X 5 
    print(npImage[0:5, 0:5])
    print()

    m = npImage.shape[0] # qtd lines
    n = npImage.shape[1] # qtd cols
    for x in range(1, m-2):
        for y in range (1, n-2):
            w = npImage[x-1:x+2 , y-1:y+2]
            #print(x,y)
            #print(w)
            #print(np.mean(w).astype(int))
            npImageFilter[x,y] = np.mean(w).astype(int)
    
    # values os a windows 5 X 5 
    print(npImage[0:5, 0:5])        
    #Convert ndarray image to Pillow image
    image2 = Image.fromarray(npImageFilter)
    #image2.show()
    #show image on notebook
    plt.imshow(image2)

# %%
#create two columns plot
fig = plt.figure(figsize=(10,5))
plt1 = plt.subplot(1,2,1)
plt2 = plt.subplot(1,2,2)

plt1.title.set_text('Original image')
plt2.title.set_text('Image with noise')

plt1.imshow(image, cmap='gray')
plt2.imshow(img_noise, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22344/2426847977.py in <module>
#       7 plt2.title.set_text('Image with noise')
#       8
# ----> 9 plt1.imshow(img, cmap='gray')
#      10 plt2.imshow(img_noise, cmap='gray')
#
# NameError: name 'img' is not defined

# %%
if __name__ == "__main__":
    main()
# Out:
# [[23 22 17 45 53]
#  [25 35 51 64 66]
#  [32 42 66 59 54]
#  [49 52 57 37 36]
#  [45 44 30 17 17]]
#
# [[23 22 17 45 53]
#  [25 35 51 64 66]
#  [32 42 66 59 54]
#  [49 52 57 37 36]
#  [45 44 30 17 17]]
